# %%
# !pip install textblob

# %%
import pandas as pd
from textblob import TextBlob

# %%
import pandas as pd

data = {
    "Review": [
        "The product is amazing and works perfectly",
        "Very bad experience, I hate this item",
        "It is okay, not great but not bad",
        "Excellent service and fast delivery",
        "Worst purchase ever"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                        Review
# 0  The product is amazing and works perfectly
# 1       Very bad experience, I hate this item
# 2           It is okay, not great but not bad
# 3         Excellent service and fast delivery
# 4                         Worst purchase ever

# %%
# Install TextBlob (run once)
# !pip install textblob

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df["Sentiment"] = df["Review"].apply(get_sentiment)
df
# Out:
#                                        Review Sentiment
# 0  The product is amazing and works perfectly  Positive
# 1       Very bad experience, I hate this item  Negative
# 2           It is okay, not great but not bad  Positive
# 3         Excellent service and fast delivery  Positive
# 4                         Worst purchase ever  Negative

# %%
sentiment_count = df["Sentiment"].value_counts()
print(sentiment_count)
# Out:
# Sentiment
# Positive    3
# Negative    2
# Name: count, dtype: int64

# %%
# !pip install plotly

# %%
import plotly.express as px

fig = px.pie(values=sentiment_count.values,
             names=sentiment_count.index,
             title="Sentiment Analysis Results")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print("===== INSIGHTS =====")
print("1. Majority of reviews are positive.")
print("2. Some customers reported negative experiences.")
print("3. Business can improve product quality to reduce negative feedback.")
# Out:
# ===== INSIGHTS =====
# 1. Majority of reviews are positive.
# 2. Some customers reported negative experiences.
# 3. Business can improve product quality to reduce negative feedback.
